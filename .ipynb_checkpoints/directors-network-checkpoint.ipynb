# %%
import pandas
import math

# %%
df = pandas.read_csv('company_directorships.csv')

df.software_background = df.software_background.map(lambda x: x == 't')
df.sample(5)
# Out:
#                       company_name  cikcode  \
# 11036            STAAR SURGICAL CO   718937
# 284    AgEagle Aerial Systems Inc.     8504
# 4404         FIRST BUSEY CORP /NV/   314489
# 11152                    STEPAN CO    94049
# 9546                    PFIZER INC    78003
#
#                               director_name  software_background  start_date  \
# 11036                        BARRY CALDWELL                False  2011-04-15
# 284                           DEDE P. JONES                False  2008-05-07
# 4404                     FREDERIC L. KENNEY                False  2019-04-11
# 11152                        JAN STERN REED                False  2016-03-24
# 9546   SUSAN DESMOND-HELLMANN, M.D., M.P.H.                 True  2021-03-12
#
#          end_date
# 11036  2014-05-05
# 284    2008-05-07
# 4404   2024-04-12
# 11152  2025-03-25
# 9546   2022-03-17

# %%
compensation_and_demographics_raw = pandas.read_csv('director-details.csv')
compensation_and_demographics_raw['NAME'] = compensation_and_demographics_raw.name.str.upper()


# TASK 2 CHANGE 1
# This common gender function ignores the edge case of if the gender split is equal
# def most_common(series):
#    mode_values = series.mode()
#    if len(mode_values) > 0:
#        return mode_values[0]
#    return None

# This function accounts for male and female both having the same amount, and returns 'Multiple'
def most_common(series):
    mode_values = series.mode()
    if len(mode_values) == 1:
        return mode_values[0]
    elif len(mode_values) > 1:
        return 'Multiple'
    return None
    
compensation_and_demographics = pandas.DataFrame({
    'age': compensation_and_demographics_raw.groupby('NAME').age.max(),
    'compensation': compensation_and_demographics_raw.groupby('NAME').compensation.sum(),
    'gender': compensation_and_demographics_raw.groupby('NAME').gender.agg(most_common)
})
compensation_and_demographics['log_compensation'] = (1 + compensation_and_demographics.compensation).map(math.log10)
compensation_and_demographics
# Out:
#                       age  compensation  gender  log_compensation
# NAME
# A. CATHERINE NGO       64       1006154  female          6.002665
# A. EUGENE WASHINGTON   70        324871    male          5.511712
# A. F. PETROCELLI       80         47000    male          4.672107
# A. FARAZ ABBASI        52        113631    male          5.055501
# A. LARRY CHAPMAN       78        259500    male          5.414139
# ...                   ...           ...     ...               ...
# ZACKARY IRANI          58        360103    male          5.556428
# ZAHID AFZAL            62             0    male          0.000000
# ZENA SRIVATSA ARNOLD   46        189960  female          5.278664
# ZENON S. NIE           73        202703    male          5.306862
# ZHONGLI LIU            64          7043    male          3.847819
#
# [5421 rows x 4 columns]

# %%
compensation_and_demographics.gender.value_counts(dropna=False)
# Out:
# gender
# male       3850
# female     1550
# None         19
# unknown       2
# Name: count, dtype: int64

# %%
directorship_counts = df.groupby('director_name').company_name.nunique().sort_values()
directorship_counts
# Out:
# director_name
# A CHARLENE SULLIVAN, PH.D.     1
# MICHAEL L. KUTA                1
# MICHAEL L. LARUSSO             1
# MICHAEL L. MILLER              1
# MICHAEL L. OWENS               1
#                               ..
# MARTIN L. FLANAGAN            13
# ANN BARNETT STERN             13
# TERESA M. RESSEL              13
# BRUCE L. CROCKETT             13
# ALBERT R. DOWDEN              14
# Name: company_name, Length: 11827, dtype: int64

# %%
# TASK 2 CHANGE 2d
# This plot has no labelling in it, and is confusing and ill-described
# directorship_counts.value_counts().sort_index().map(math.log10).plot()

# Below is added labels and a log scale to better showcase the data

import matplotlib.pyplot as plt

directorship_counts.value_counts().sort_index().map(math.log10).plot()

plt.title("Log Distribution of Directorship Count Frequencies")
plt.xlabel("Number of Companies a Person is a Director For")
plt.ylabel("log10(Frequency)")
plt.grid(True)
plt.show()

# %%
import networkx
import networkx.algorithms
graph = networkx.Graph()

# %%
people = []
companies = []
for company_name, director_name in zip(df.company_name, df.director_name):
    graph.add_edge(company_name, director_name)
    people.append(director_name)
    companies.append(company_name)

# %%
# TASK 2 CHANGE 3
# This assumes the biggest connected graph is simply the first in the array, however 
# networkx.connect_components returns an unordered set of sets. 
# biggest_connected_graph = graph.subgraph(list(networkx.connected_components(graph))[0])

# This change ensures you always receive the biggest connected component
largest_cc = max(networkx.connected_components(graph), key=len)
biggest_connected_graph = graph.subgraph(largest_cc)

# %%
# %%time
centrality = pandas.DataFrame({
    'eigen': pandas.Series(networkx.eigenvector_centrality(biggest_connected_graph)),
    'degree': pandas.Series(networkx.algorithms.degree_centrality(biggest_connected_graph)),
    # TASK 1 CODE ADJUSTMENT
    # Kernel took 430 seconds to process this
    'betweenness': pandas.Series(networkx.betweenness_centrality(biggest_connected_graph)),

})
centrality['is_person'] = centrality.index.map(lambda x: x in people)
# Out:
# CPU times: user 7min 8s, sys: 1.33 s, total: 7min 9s
# Wall time: 7min 14s

# %%
# TASK 2 CHANGE 4
# In the case that one of the values here is missing, that data point gets silently dropped due to left and right
# index needing to be true.
# people_df = centrality[centrality.is_person].merge(compensation_and_demographics, left_index=True, right_index=True)

# Below a how='left' check occurs to make sure pandas won't default to 'inner' so that the left dataframe (centrality)
# is kept regardless of if there is a value in the right dataframe (demographic data)

# Merge with warning in case of dropped data
people_df = centrality[centrality.is_person].merge(
    compensation_and_demographics, left_index=True, right_index=True, how='left'
)

# Check for missing values after merge
missing_data = people_df[people_df['age'].isna()]
if not missing_data.empty:
    print("Warning: Some people have no demographic data.")

# %%
people_df.sort_values('eigen', ascending=False)
# Out:
#                             eigen    degree   betweenness  is_person  age  \
# ELIZABETH KRENTZMAN  1.024389e-01  0.001585  1.394057e-07       True   65
# CAROL DECKBAR        1.024389e-01  0.001585  1.394057e-07       True   62
# ELI JONES            1.024389e-01  0.001585  1.394057e-07       True   63
# DOUGLAS SHARP        1.024389e-01  0.001585  1.394057e-07       True   50
# JAMES "JIM" LIDDY    1.024389e-01  0.001585  1.394057e-07       True   65
# ...                           ...       ...           ...        ...  ...
# JOHN J. GEBBIA       8.400282e-35  0.000122  0.000000e+00       True   86
# ANDREW S. BORODACH   8.342633e-35  0.000122  0.000000e+00       True   56
# LAWRENCE A. KOBRIN   8.342633e-35  0.000122  0.000000e+00       True   91
# NANCY J. FLOYD PRUE  8.342633e-35  0.000122  0.000000e+00       True   70
# RICHARD P. HOWARD    8.342633e-35  0.000122  0.000000e+00       True   78
#
#                      compensation  gender  log_compensation
# ELIZABETH KRENTZMAN       3408245  female          6.532531
# CAROL DECKBAR               43263  female          4.636127
# ELI JONES                 3063255    male          6.486183
# DOUGLAS SHARP                   0    male          0.000000
# JAMES "JIM" LIDDY           27531    male          4.439838
# ...                           ...     ...               ...
# JOHN J. GEBBIA             120000    male          5.079185
# ANDREW S. BORODACH              0    male          0.000000
# LAWRENCE A. KOBRIN          30356    male          4.482259
# NANCY J. FLOYD PRUE         50356  female          4.702060
# RICHARD P. HOWARD               0    male          0.000000
#
# [3742 rows x 8 columns]

# %%
df[df.director_name == 'ELIZABETH KRENTZMAN']
# Out:
#                                            company_name  cikcode  \
# 6297        Invesco Advantage Municipal Income Trust II   908993
# 6352                                  Invesco Bond Fund     5094
# 6407    Invesco California Value Municipal Income Trust   895531
# 6462                       Invesco High Income Trust II   846671
# 6512       Invesco Municipal Income Opportunities Trust   835333
# 6546                Invesco Municipal Opportunity Trust   884152
# 6601                            Invesco Municipal Trust   877463
# 6656  Invesco Pennsylvania Value Municipal Income Trust   895528
# 6706             Invesco Quality Municipal Income Trust   885125
# 6740                        Invesco Senior Income Trust  1059386
# 6793      Invesco Trust for Investment Grade Municipals   880892
# 6848  Invesco Trust for Investment Grade New York Mu...   883265
# 6898               Invesco Value Municipal Income Trust   885601
#
#             director_name  software_background  start_date    end_date
# 6297  ELIZABETH KRENTZMAN                False  2021-06-22  2024-07-02
# 6352  ELIZABETH KRENTZMAN                False  2021-06-22  2024-07-02
# 6407  ELIZABETH KRENTZMAN                False  2021-06-22  2024-07-02
# 6462  ELIZABETH KRENTZMAN                False  2021-06-22  2024-07-02
# 6512  ELIZABETH KRENTZMAN                False  2021-06-22  2024-07-02
# 6546  ELIZABETH KRENTZMAN                False  2021-06-22  2024-07-02
# 6601  ELIZABETH KRENTZMAN                False  2021-06-22  2024-07-02
# 6656  ELIZABETH KRENTZMAN                False  2021-06-22  2024-07-02
# 6706  ELIZABETH KRENTZMAN                False  2021-06-22  2024-07-02
# 6740  ELIZABETH KRENTZMAN                False  2021-06-22  2024-07-02
# 6793  ELIZABETH KRENTZMAN                False  2021-06-22  2024-07-02
# 6848  ELIZABETH KRENTZMAN                False  2021-06-22  2024-07-02
# 6898  ELIZABETH KRENTZMAN                False  2021-06-22  2024-07-02

# %%
import sklearn.cluster

# %%
import sklearn.preprocessing
robust_scaler = sklearn.preprocessing.RobustScaler()
age_and_demographics_scaled = robust_scaler.fit_transform(people_df[['age', 'log_compensation', 'degree', 'eigen']])

# %%
dbscan = sklearn.cluster.DBSCAN(eps=0.4)
people_df['cluster_id'] = dbscan.fit_predict(age_and_demographics_scaled)
people_df.cluster_id.value_counts()
# Out:
# cluster_id
#  1    3117
#  0     385
#  2     109
# -1      72
#  3      24
#  4      19
#  7       8
#  6       5
#  5       3
# Name: count, dtype: int64

# %%
people_df.plot.scatter(x='age', y='log_compensation', c='cluster_id', cmap="rainbow", s=4)
# Out:
# <Axes: xlabel='age', ylabel='log_compensation'>

# %%
people_df.loc['ELIZABETH KRENTZMAN']
# Out:
# eigen               0.102439
# degree              0.001585
# betweenness              0.0
# is_person               True
# age                       65
# compensation         3408245
# gender                female
# log_compensation    6.532531
# cluster_id                 2
# Name: ELIZABETH KRENTZMAN, dtype: object

# %%
# BELOW IS THE INCLUDED VISUALISATIONS FOR TASK 5

# %%
# Visualisation 1: Top 13 eigenvector centrality
top_eigen = people_df.sort_values('eigen', ascending=False).head(13)
fig1, ax1 = plt.subplots()
top_eigen['eigen'].plot(kind='barh', ax=ax1, color='skyblue')
ax1.set_title('Top 13 Directors by Eigenvector Centrality')
ax1.set_xlabel('Eigenvector Centrality')
plt.tight_layout()

# Visualisation 2: Centrality vs Log Compensation
fig2, ax2 = plt.subplots()
ax2.scatter(people_df['eigen'], people_df['log_compensation'], alpha=0.6, c='navy')
ax2.set_xlabel('Eigenvector Centrality')
ax2.set_ylabel('Log Compensation')
ax2.set_title('Influence vs Compensation')
plt.tight_layout()
plt.show()

# Visualisation 3: Distribution of Director Influence (Eigenfactor Centrality)
eigen_scores = people_df['eigen'].dropna()
num_bins = 4
binned = pandas.cut(eigen_scores, bins=num_bins)

binned_counts = binned.value_counts().sort_index()

binned_counts.plot(kind='bar', color='mediumseagreen', edgecolor='black')
plt.title('Distribution of Director Influence (Eigenvector Centrality)')
plt.xlabel('Eigenvector Centrality Range')
plt.ylabel('Number of People')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.grid(axis='y')
plt.show()
print(binned_counts)

# Visualisation 4: Age vs Compensation (Clustered) (Seen in code above)
robust_scaler = sklearn.preprocessing.RobustScaler()
age_and_demographics_scaled = robust_scaler.fit_transform(
    people_df[['age', 'log_compensation', 'degree', 'eigen']]
)

dbscan = sklearn.cluster.DBSCAN(eps=0.4)
people_df['cluster_id'] = dbscan.fit_predict(age_and_demographics_scaled)

plt.figure(figsize=(10, 6))
scatter = plt.scatter(
    people_df['age'],
    people_df['log_compensation'],
    c=people_df['cluster_id'],
    cmap="rainbow",
    s=10,
    alpha=0.7,
    edgecolors='none'
)

plt.title("DBSCAN Clustering of Directors by Age and Compensation")
plt.xlabel("Age")
plt.ylabel("Log(Compensation)")
# Added to explain confusing y axis
ticks = [3, 4, 5, 6, 7]
labels = ['1k', '$10k', '$100k', '$1M', '$10M']
plt.yticks(ticks, labels)
plt.tight_layout()
plt.show()

# Visualisation 5: Compensation by Gender
fig4, ax4 = plt.subplots()
people_df.boxplot(column='log_compensation', by='gender', ax=ax4)
ax4.set_title('Compensation by Gender')
ax4.set_ylabel('Log Compensation')
plt.suptitle('')
plt.tight_layout()

# Visualisation 6: Histogram of Directorship Counts
fig5, ax5 = plt.subplots()
directorship_counts.value_counts().sort_index().map(math.log10).plot()

ax5.set_title("Log Distribution of Directorship Count Frequencies")
ax5.set_xlabel("Number of Companies a Person is a Director For")
ax5.set_ylabel("log10(Frequency)")
plt.grid(True)
plt.show()

# Visualization 7: Centrality Measures Correlation Heatmap
plt.figure(figsize=(8, 6))
corr = people_df[['degree', 'eigen', 'betweenness', 'log_compensation']].corr()
im = plt.imshow(corr, cmap='coolwarm', vmin=-1, vmax=1)
plt.colorbar(im, fraction=0.046, pad=0.04)
plt.xticks(range(len(corr)), corr.columns, rotation=45)
plt.yticks(range(len(corr)), corr.columns)
for i in range(len(corr)):
    for j in range(len(corr)):
        plt.text(j, i, f"{corr.iloc[i, j]:.2f}", ha='center', va='center', color='black')
plt.title("Correlation Between Centrality Measures and Compensation")
plt.tight_layout()
plt.show()
# Out:
# eigen
# (-0.000102, 0.0256]    3729
# (0.0256, 0.0512]          0
# (0.0512, 0.0768]          0
# (0.0768, 0.102]          13
# Name: count, dtype: int64
